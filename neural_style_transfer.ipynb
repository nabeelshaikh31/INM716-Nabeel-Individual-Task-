# %%
# !pip install opencv-python
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %%
def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# %%
content_image = load_image('c1.jpg')
style_image = load_image('s1.jpg')

# %%
content_image.shape
# Out:
# TensorShape([1, 509, 509, 3])

# %%
plt.imshow(np.squeeze(content_image))
plt.show()
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
for i in range(0, 3):
    stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
    content_image = stylized_image
plt.imshow(np.squeeze(stylized_image))
plt.show()
# Out:
# 2022-05-13 18:27:46.568402: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
cv2.imwrite('o1.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image = load_image('c2.jpg')
style_image = load_image('s3.jpg')

plt.imshow(np.squeeze(content_image))
plt.show()
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('o2.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image = load_image('c3.jpg')
style_image = load_image('s4.jpg')

plt.imshow(np.squeeze(content_image))
plt.show()
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('o3.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image = load_image('c4.jpg')
style_image = load_image('s2.jpg')

plt.imshow(np.squeeze(content_image))
plt.show()
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('o4.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image = load_image('c5.jpg')
style_image = load_image('s5.jpg')

plt.imshow(np.squeeze(content_image))
plt.show()
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('o5.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image = load_image('c6.jpg')
style_image = load_image('s6.jpg')

plt.imshow(np.squeeze(content_image))
plt.show()
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('o6.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image = load_image('c7.jpg')
style_image = load_image('s7.jpg')

plt.imshow(np.squeeze(content_image))
plt.show()
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
for i in range(0, 2):
    stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
    content_image = stylized_image
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('o7.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image = load_image('c8.jpg')
style_image = load_image('s8.jpg')

plt.imshow(np.squeeze(content_image))
plt.show()
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
for i in range(0, 1):
    stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
    content_image = stylized_image
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('o8.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image = load_image('c9.jpg')
style_image = load_image('s9.jpg')

plt.imshow(np.squeeze(content_image))
plt.show()
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
for i in range(0, 1):
    stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
    content_image = stylized_image
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('o9.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image = load_image('c10.jpg')
style_image = load_image('s11.jpg')

plt.imshow(np.squeeze(content_image))
plt.show()
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
for i in range(0, 1):
    stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
    content_image = stylized_image
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('o10.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
content_image = load_image('c11.jpg')
style_image = load_image('s10.jpeg')

plt.imshow(np.squeeze(content_image))
plt.show()
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
for i in range(0, 3):
    stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
    content_image = stylized_image
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('o11.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True
